# %% [markdown]
# <a href="https://colab.research.google.com/github/sajalgoyal007/AIML-Training-Projects/blob/main/Practice/Statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
arr = np.array([2, 3, 4, 6, 7, 8, 9, 12, 13, 16, 17, 23, 25, 27, 34, 37, 201])
arr
# Out:
# array([  2,   3,   4,   6,   7,   8,   9,  12,  13,  16,  17,  23,  25,
#         27,  34,  37, 201])

# %%
Q1 = np.percentile(arr, 25)
Q2 = np.percentile(arr, 50)
Q3 = np.percentile(arr, 75)
IQR = Q3 - Q1
IQR
# Out:
# np.float64(18.0)

# %%
UF = Q3 + 1.5 * (IQR)   #Upper fance
LF = Q1 - 1.5 * (IQR)   #Lower fance
print(UF)
print(LF)
# Out:
# 52.0
# -20.0

# %%
l = []
for i in  arr:
  if i>=LF and i<=UF:
    l.append(int(i))
arr2 = np.array(l)

# %%
print(arr)
print(arr2)
# Out:
# [  2   3   4   6   7   8   9  12  13  16  17  23  25  27  34  37 201]
# [ 2  3  4  6  7  8  9 12 13 16 17 23 25 27 34 37]

# %%
import seaborn as sns

sns.boxplot(x=arr)
# Out:
# <Axes: >

# %%
sns.boxplot(x=arr2)
# Out:
# <Axes: >

# %% [markdown]
# #**Z-Test using the P-Value**

# %%
import numpy as np
import scipy.stats as norm

# %%
import scipy.stats as stats

# %%
sample = [172, 174, 168, 169, 171, 173, 175, 170, 169, 172]
population_mean = 170
population_std = 3
samp_mean = np.mean(sample)
samp_std = np.std(sample)
n = len(sample)

# %%
z_score = (samp_mean - population_mean)/(population_std/np.sqrt(n))

# %%
z_score
# Out:
# np.float64(1.3703203194063098)

# %%
p_value = 2*(1-stats.norm.cdf(abs(z_score)))

# %%
p_value
# Out:
# np.float64(0.17058693287143756)

# %%
alpha = 0.05

if p_value<alpha:
  print("I will reject the null hypothesis")
else:
  print("I will accept the null hypothesis")
# Out:
# I will accept the null hypothesis

# %% [markdown]
# #**T-test using p-value**

# %%
import numpy as np
from scipy import stats

# %%
sample = [172,174, 168, 169, 171, 173, 175, 170, 169, 172]
population_mean = 170
sample_mean = np.mean(sample)
sample_std = np.std(sample, ddof = 1)
n = len(sample)

# %%
t_stats = (sample_mean - population_mean)/(sample_std/np.sqrt(n))

# %%
t_stats
# Out:
# np.float64(1.7782469350914734)

# %%
p_value = 2* (1-stats.t.cdf(abs(t_stats), df = n-1))
alpha = 0.05

# %%
if p_value < alpha:
  print("I will reject the null hypothesis")
else:
  print("I will accept the null hypothesis")
# Out:
# I will accept the null hypothesis

# %% [markdown]
# #**T-Sample T-test**

# %%
import numpy as np
from scipy import stats

# %%
group_A = [85, 88, 90, 92, 87, 85, 89, 91, 86, 88]
group_B = [82, 84, 80, 83, 81, 79, 78, 85, 84, 83]

# %%
t_stats, p__value = stats.ttest_ind(group_A, group_B, equal_var=True)

# %%
t_stats
# Out:
# np.float64(5.829604009507161)

# %%
alpha = 0.05
if p__value < alpha:
  print("I will reject the null hypothesis")
else:
  print("I will accept the null hypothesis")
# Out:
# I will reject the null hypothesis

# %% [markdown]
# #**Chi-Square Test**

# %%
import numpy as np
import seaborn as sns
import pandas as pd
from scipy.stats import chi2_contingency

# %%
df = sns.load_dataset('titanic')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
contingency_table = pd.crosstab(df['sex'], df['survived'])

# %%
contingency_table
# Out:
# survived    0    1
# sex
# female     81  233
# male      468  109

# %%
chi2, p_value, dof, expected = chi2_contingency(contingency_table)

# %%
expected
# Out:
# array([[193.47474747, 120.52525253],
#        [355.52525253, 221.47474747]])

# %%
dof
# Out:
# 1

# %%
p_value
# Out:
# np.float64(1.1973570627755645e-58)

# %%
chi2
# Out:
# np.float64(260.71702016732104)

# %%
alpha = 0.05
if p_value < alpha:
  print("I will reject the null hypothesis and there is a significant relationship between sex and survival")
else:
  print("I will accept the null hypothesis")
# Out:
# I will reject the null hypothesis and there is a significant relationship between sex and survival

# %% [markdown]
# #**Annova_test**

# %%
import seaborn as sns
import pandas as pd
from scipy.stats import f_oneway

# %%
df = sns.load_dataset('titanic')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
df = df[['age', 'pclass']].dropna()

# %%
df['pclass'].unique()
# Out:
# array([3, 1, 2])

# %%
class_1 = df[df['pclass']==1]['age']
class_2 = df[df['pclass']==2]['age']
class_3 = df[df['pclass']==3]['age']

# %%
class_1
# Out:
# 1      38.0
# 3      35.0
# 6      54.0
# 11     58.0
# 23     28.0
#        ...
# 871    47.0
# 872    33.0
# 879    56.0
# 887    19.0
# 889    26.0
# Name: age, Length: 186, dtype: float64

# %%
f_stats, p_value = f_oneway(class_1, class_2, class_3)

# %%
f_stats
# Out:
# np.float64(57.44348434067624)

# %%
p_value
# Out:
# np.float64(7.487984171959213e-24)

# %%
alpha = 0.05

# %%
if p_value < alpha:
  print("I will reject the null hypothesis and these is  a significance difference between at leaast one passenger class")
else:
  print("I will accept the null hypothesis and there is no significance difference")
# Out:
# I will reject the null hypothesis and these is  a significance difference between at leaast one passenger class
