# %% [markdown]
# <a href="https://colab.research.google.com/github/sajalgoyal007/AIML-Training-Projects/blob/main/Task-2/mini_projects.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Project 1: Grade Calculator**

# %%
marks = int(input("Enter your marks: "))

if marks >= 90:
    print("Grade: A+")

elif marks >= 75:
    print("Grade: A")

elif marks >= 60:
    print("Grade: B")

elif marks >= 40:
    print("Grade: C")

else:
    print("Fail")
# Out:
# Enter your marks: 86
# Grade: A

# %% [markdown]
# **Project 2: Celsius to Fahrenheit Converter**

# %%
celsius = float(input("Enter temperature in Celsius: "))

fahrenheit = (celsius * 9/5) + 32

print(f"{celsius}°C is equal to {fahrenheit}°F")
# Out:
# Enter temperature in Celsius: 65
# 65.0°C is equal to 149.0°F

# %% [markdown]
# **Project 3: Simple Login Validation**

# %%
stored_username = "admin"
stored_password = "1234"

username = input("Enter username: ")
password = input("Enter password: ")

if username != stored_username:
    print("Incorrect Username")

elif password != stored_password:
    print("Incorrect Password")

else:
    print("Login Successful")
# Out:
# Enter username: user
# Enter password: 1234
# Incorrect Username

# %% [markdown]
# **Project 4: Factorial Calculator**

# %%
def factorial(n):
    fact = 1
    for i in range(1, n + 1):
        fact *= i
    return fact

num = int(input("Enter a number: "))

if num < 0:
    print("Factorial is not exist for negative numbers")
else:
    print("Factorial:", factorial(num))
# Out:
# Enter a number: 7
# Factorial: 5040
